# %% [markdown]
# # If - elif - else statement

# %%
#W. A P. which takes one number from 0 to 9 from the user and prints it in the word. And if the word is not from 0 to 9 then
#it should print that number is outside of the range and program should exit.
# For example:- 
# input = 1
# output = one

num= int(input("Enter the number: "))

if num == 0:
  print("ZERO")
elif num ==1:
  print("ONE")
elif num ==2:
  print("TWO")
elif num ==3:
  print("THREE")
elif num ==4:
  print("FOUR")
elif num == 5:
  print("FIVE")
elif num ==6:
  print("SIX")
elif num ==7:
  print("SEVEN")
elif num ==8:
  print("EIGHT")
elif num ==9:
  print("NINE")
else:
  print("The Number is not in the range 0-9")
# Out:
# Enter the number: 10
# The Number is not the range 0-9

# %%
#W. A P. to implement calculator but the operation to be done and two numbers will be taken as input from user:-
#Operation console should show below:-
#     Please select any one operation from below:-
#         * To add enter 1
#         * to subtract enter 2
#         * To multiply enter 3
#         * To divide enter 4
#         * To divide and find quotient enter 5
#         * To divide and find remainder enter 6
#         * To divide and find num1 to the power of num2 enter 7
#         * To Come out of the program enter 8


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
oper = int(input("""
Enter the respective number for operation:
1. Add
2. Subtract
3. Multiply
4. Divide
5. Quotient
6. Remainder
7. num1 to power of num2
8. Exit
"""))
if oper == 1:
  print(num1 + num2)
elif oper == 2:
  if num1>num2:
    print(num1-num2)
  else:
    print(num2-num1)
elif oper == 3:
  print(num1 * num2)
elif oper == 4:
  print(num1/num2)
elif oper == 5:
  print(num1//num2)
elif oper == 6:
  print(num1%num2)
elif oper == 7:
  print(num1 ** num2)
elif oper == 8:
  print("Thank You")
else:
  print(" Invalid Option")
# Out:
# Enter first number: 5
# Enter second number: 3
#
# Enter the respective number for operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Quotient
# 6. Remainder
# 7. num1 to power of num2
# 8. Exit
# 6
# 2.0

# %%
#W A P to check whether a year entered by user is an leap year or not?
#Check with below input:-
    #leap year:- 2012, 1968, 2004, 1200, 1600,2400
    #Non-leap year:- 1971, 2006, 1700,1800,1900

year= int(input("Enter the Year: "))

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print(f"{year} is a Leap Year")
    else:
      print(f"{year} is not a Leap Year")
  else:
    print(f"{year} is a Leap Year")
else:
  print(f"{year} is not a Leap Year")
# Out:
# Enter the Year: 2020
# 2020 is a Leap Year

# %%
#W A P which takes one number from the user and checks whether it is an even or odd number?, If it even then prints number is 
#even number else prints that number is odd number.

a = int(input("Enter the number: "))
if a % 2 == 0:
  print(f"{a} is Even Number")
else:
  print(f"{a} is Odd Number")
# Out:
# Enter the number: 4
# 4 is Even Number

# %%
#W A P which takes two numbers from the user and prints below output:-
#     1. num1 is greater than num2 if num1 is greater than num2
#     2. num1 is smaller than num2 if num1 is smaller than num2
#     3. num1 is equal to num2 if num1 and num2 are equal

#Note:- 1. Do this problem using if - else 
#       2. Do this using ternary operator


numb1 = input(" Enter first number: ")
numb2 = input(" Enter second number: ")

if numb1 > numb2:
  print(f"{numb1} is greater than {numb2}")
elif numb1 < numb2:
  print(f"{numb1} is smaller than {numb2}")
else:
  print(f"{numb1} is equal to {numb2}")
# Out:
#  Enter first number: 5
#  Enter second number: 6
# 5 is smaller than 6

# %%
#2. Do this using ternary operator

numb1 = input(" Enter first number: ")
numb2 = input(" Enter second number: ")

note1 = f" {numb1} is greater than {numb2}"
note2 = f" {numb1} is smaller than {numb2}"
note3 = f" {numb1} is equal to {numb2}"

res= note1 if numb1>numb2 else note2 if numb1<numb2 else note3

print(res)
# Out:
#  Enter first number: 6
#  Enter second number: 5
#  6 is greater than 5

# %%
#W A P which takes three numbers from the user and prints below output:-
#     1. num1 is greater than num2 and num3 if num1 is greater than num2 and num3
#     2. num2 is greater than num1 and num3 if num2 is greater than num1 and num3
#     3. num3 is greater than num1 and num2 if num3 is greater than num1 and num2

#Note:- 1. Do this problem using if - elif - else 
#       2. Do this using ternary operator

numb1 = eval(input("Enter first number: "))
numb2 = eval(input("Enter second number: "))
numb3 = eval(input("Enter third number: "))
if numb1 == numb2 and numb2 == numb3:
  print("All Numbers are Equal")
elif numb1 > numb2 and numb1 > numb3:
  print(f"{numb1} is greater than {numb2} and {numb3}")
elif numb2 > numb3:
  print(f"{numb2} is greater than {numb1} and {numb3}")
else:
  print(f"{numb3} is greater than {numb1} and {numb2}")
# Out:
# Enter first number: 10.5
# Enter second number: 10.75
# Enter third number: 10.55
# 10.75 is greater than 10.5 and 10.55

# %%
# 2. Do this using ternary operator

numb1 = eval(input("Enter first number: "))
numb2 = eval(input("Enter second number: "))
numb3 = eval(input("Enter third number: "))

note1 = f"{numb1} is greater than {numb2} and {numb3}"
note2 = f"{numb2} is greater than {numb1} and {numb3}"
note3 = f"{numb3} is greater than {numb1} and {numb2}"
note4 = " All numbers are Equal"

result = note1 if numb1>numb2 and numb1>numb2 else note2 if numb2>numb3 else note4 if num1 == numb2 and numb2 == numb3 else note3

print(result)
# Out:
# Enter first number: 10.5
# Enter second number: 0.25
# Enter third number: 7.55
# 10.5 is greater than 0.25 and 7.55

# %% [markdown]
# # Loops - for loop, while loop

# %%
#Write a Python program to find the length of the my_str using loop:-

#Input:- 'Write a Python program to find the length of the my_str'
#Output:- 55

ip = 'Write a Python program to find the length of the my_str'

count = 0

for i in ip:
  count+=1
print(count)
# Out:
# 55

# %%
#Write a Python program to find the total number of times letter 'p' is appeared in the below string using loop:-
    
#Input:- 'peter piper picked a peck of pickled peppers.\n'
#Output:- 9

ip= 'peter piper picked a peck of pickled peppers'

count= 0

for i in ip:
  if i == 'p':
    count+=1
print(count)
# Out:
# 9

# %%
#Write a Python Program, to print all the indexes of all occurences of letter 'p' appeared in the string using loop:-
    
#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

ip= 'peter piper picked a peck of pickled peppers'

for i in range(len(ip)):
  if ip[i] == 'p':
    print(i)
# Out:
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']

ip= 'peter piper picked a peck of pickled peppers.'
out_lst = []
out_str = ''
for i in ip:
  if i == " " or i== ".":
    out_lst.append(out_str)
    out_str=''
  else:
    out_str+=i
print(out_lst)
# Out:
# ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'peppers pickled of peck a picked piper peter'

ip= 'peter piper picked a peck of pickled peppers.'
out_lst = []
out_str = ''
for i in ip:
  if i == " " or i== ".":
    out_lst.append(out_str)
    out_str=''
  else:
    out_str+=i
for j in range(1,len(out_lst)+1):
  print(out_lst[-j], end=" ")
# Out:
# peppers pickled of peck a picked piper peter

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- '.sreppep delkcip fo kcep a dekcip repip retep'

ip = 'peter piper picked a peck of pickled peppers.'

# for i in range(1,len(ip)+1):
#   print(ip[-i], end="")

i =0
while i < len(ip):
  i+=1
  print(ip[-i], end ="")
# Out:
# .sreppep delkcip fo kcep a dekcip repip retep

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'retep repip dekcip a kcep fo delkcip sreppep'

ip= 'peter piper picked a peck of pickled peppers.'
out_lst = []
out_str = ''
out_str2 = ''
for i in ip:
  if i == " " or i== ".":
    out_lst.append(out_str)
    out_str=''
  else:
    out_str+=i

for j in range(0,len(out_lst)):
  for k in range(1,len(out_lst[j])+1):
    out_str2 = out_lst[j]
    print(out_str2[-k] , end= "")
  print(end=" ")
# Out:
# .sreppep delkcip fo kcep a dekcip repip retep

# %%
#Write a python program to find below output using loop:-

#Input:- 'peter piper picked a peck of pickled peppers.'
#Output:- 'Peter Piper Picked A Peck Of Pickled Peppers'  ---------> # print(ip.title())

ip= 'peter piper picked a peck of pickled peppers.'

out_lst = []
out_str = ''
for i in ip:
  if i == " " or i== ".":
    out_lst.append(out_str)
    out_str=''
  else:
    out_str+=i
for j in range(0,len(out_lst)):
    out_str2 = out_lst[j]
    print(out_str2.capitalize(), end=" ")
# Out:
# Peter Piper Picked A Peck Of Pickled Peppers

# %%
#Write a python program to find below output using loop:-

#Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.'
#Output:- 'Peter piper picked a peck of pickled peppers' ------> print(ip.captilize())

ip='Peter Piper Picked A Peck Of Pickled Peppers.'

out_lst = []
out_str = ''
for i in ip:
  if i == " " or i== ".":
    out_lst.append(out_str)
    out_str=''
  else:
    out_str+=i
for j in range(0,len(out_lst)):
  for k in range(1,len(out_lst)):
    out_lst[k]= out_lst[k].casefold()
  out_str2 = out_lst[j]
  print(out_str2, end=" ")
# Out:
# Peter piper picked a peck of pickled peppers

# %%
#Write a python program to implement index method using loop. If sub_str is found in my_str then it will print the index
# of first occurrence of first character of matching string in my_str:-

#Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Pickl'
#Output:- 29 ----------> print(my_str.index(sub_str))

my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Pickl'

count_ind= 0

for i in range(len(lst)):
  if my_str[i:i+len(sub_str)] == sub_str[0:len(sub_str)]:
    break
  else:
    count_ind+=1
print(count_ind)
# Out:
# 29

# %%
#Write a python program to implement replace method using loop. If sub_str is found in my_str then it will replace the first 
#occurrence of sub_str with new_str else it will will print sub_str not found:-

#Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck', new_str = 'Pack'
#Output:- 'Peter Piper Picked A Pack Of Pickled Peppers.'

my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'
new_str = 'Pack'

lst= list(my_str)
lst2= list(sub_str)
lst3=list(new_str)
out_str= ''
outstr1=''
# len_sub_str= len(sub_str)
for i in range(len(lst)):
  if lst[i:i+len(sub_str)] == lst2[0:len(sub_str)]:
    lst[i:i+len(sub_str)] = lst3[0:len(new_str)]

for j in range(len(lst)):
  out_str = lst[j]
  outstr1+=out_str
print(outstr1)
# Out:
# Peter Piper Picked A Pack Of Pickled Peppers Pack.

# %%
#Write a python program to find below output (implements rjust and ljust) using loop:-

#Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.', sub_str = 'Peck', 
#Output:- '*********************Peck********************'

my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'

lst= list(my_str)
lst2= list(sub_str)

out_str= ''

for i in range(len(lst)+1):
  if my_str[i:i+len(sub_str)] == sub_str[0:len(sub_str)]:
    break
  else:
    lst[i]= '*'
for k in range(len(lst)):
  if my_str[-k:-k-len(sub_str):-1] == sub_str[-1:-len(sub_str)-1:-1]:
    break
  else:
    lst[-k]= '*'

for j in range(len(lst)):
  out_str = lst[j]
  print(out_str, end="")
# Out:
# *********************Peck********************

# %%
my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.'
sub_str = 'Peck'

ind= my_str.index(sub_str)
str1 = sub_str.rjust(ind,'*')
len1= len(my_str)
str1.ljust(len1,'*')
# Out:
# '*****************Peck************************'

# %%
#Write a python program to find below output using loop:-

#Input:- 'This is Python class', sep = 'is'
#Output:- ['This', 'is', 'Python class']

ip='This is Python class'
sep=' is'
out_lst=[]
out_str=''
ind = ip.index('is',3)

for i in range(len(ip)+1):
  if i ==ind-1 or i== ind+len(sep)-1 or i == len(ip):
    out_lst.append(out_str)
    out_str=""
  else:
    out_str+=ip[i]
print(out_lst)
# Out:
# ['This', 'is', 'Python class']

# %%
#Write a python program which takes one input string from user and encode it in below format:-
#1  # Input:- 'Python'
    #Output:- 'R{vjqp'
        
ip = 'Python'
out_str=''
for i in ip:
    out_str+=chr(ord(i)+2)
print(out_str)

#2 #Input:- 'Python'
   #Output:- 'Rwvfql'
        
out_str2 = ''        
for i in range(len(ip)):
  if i % 2 == 0:
    out_str2 += chr(ord(ip[i])+2)
  else:
    out_str2 += chr(ord(ip[i])-2)
print(out_str2)

        
        
#3. #Input:- 'Python'
    #Output:- 'R{vfml'

out_str3 = ''        
for i in range(len(ip)):
  if i <= 2:
    out_str3 += chr(ord(ip[i])+2)
  else:
    out_str3 += chr(ord(ip[i])-2)
print(out_str3)
# Out:
# R{vjqp
# Rwvfql
# R{vfml
