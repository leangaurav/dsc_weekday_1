# %%
#Declare an int value and store it in a variable. 

a= 10
print(a)

#Check the type and print the id of the same.

print(type(a), id(a))
# Out:
# 10
# <class 'int'> 10914784

# %%
#Take one int value between 0 - 256.
#Assign it to two different variables.
#Check the id of both the variables. It should come same. Check why?

a=256
b=256

print(id(a),id(b))

print(a is b)



#Take one int value either less than -5 or greater than 256.
#Assign it to two different variables.
#Check the id of both the variables. It should come different.Check why?

c=257
d=257

print(id(c),id(d))

print(c is d)
# Out:
# 10922656 10922656
# True
# 140630530554480 140630530555120
# False

# %%
#Arithmatic Operations on integers
#Take two different intger values.
#Store them in two different variables.
#Do below operations on them:-
    #Find sum of both numbers
    #Find differce between them
    #Find the product of both numbers.
    #Find value after dividing first num with second number
    #Find the remainder after dividing first number with second number
    #Find the quotient after dividing first number with second number
    #Find the result of first num to the power of second number.

a = int(input('Enter First Number: '))
b = int(input('Enter Second Number: '))

c= a+b
print(f"Sum of {a} and {b} is {c}")

if a>b:
  d= a-b
else:
  d= b-a
print(f"Difference between {a} and {b} is {d}")

e= a*b
print(f"Product of {a} and {b} is {e}")

f= a/b
print(f"Value after dividing {a} with {b} is {f}")

g= a%b
print(f"Remainder after dividing {a} with {b} is {g}")

h= a//b
print(f"Quotient after dividing {a} with {b} is {h}")

i= a**b
print(f"{a} to the power {b} is {i}")
# Out:
# Enter First Number: 5
# Enter Second Number: 6
# Sum of 5 and 6 is 11
# Difference between 5 and 6 is 1
# Product of 5 and 6 is 30
# Value after dividing 5 with 6 is 0.8333333333333334
# Remainder after dividing 5 with 6 is 5
# Quotient after dividing 5 with 6 is 0
# 5 to the power 6 is 15625

# %%
#Comparison Operators on integers
#Take two different intger values.
#Store them in two different variables.
#Do below operations on them:-
    #Compare se two numbers with below operator:-
        #Greater than, '>'
        #Smaller than, '<'
        #Greater than or equal to, '>='
        #Less than or equal to, '<='
#Observe their output(return type should be boolean)

a = int(input("Enter first number: "))
b= int(input("Enter second number: "))

print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# Enter first number: 10
# Enter second number: 20
# False
# True
# False
# True

# %%
#Equality Operator
#Take two different intger values.
#Store them in two different variables.
#Equuate them using equality operator (==, !=)
#Observe the output(return type should be boolean)

a = int(input('Enter First Number: '))
b = int(input('Enter Second Number:'))

print(a==b)
print(a!=b)
# Out:
# Enter First Number: 10
# Enter Second Number:0
# False
# True

# %%
#Logical operators
#Observe the output of below code
#Cross check the output manually

print(10 and 20)       #----------------------------------------->Output is 20
# 10 - True and 20- True
# output -20

print(0 and 20)        #----------------------------------------->Output is 0
#  0- False
# output - 0

print(20 and 0)        #----------------------------------------->Output is 0
# 20 - True and 0 - False
# output - 0

print(0 and 0)         #----------------------------------------->Output is 0
#  0- False and 0- False
# Output -0

print(10 or 20)        #----------------------------------------->Output is 10

#  10- True
# output - 10 - No need to verify for the next Value!

print(0 or 20)         #----------------------------------------->Output is 20
#  0- False 20- True
#  Output - 20

print(20 or 0)         #----------------------------------------->Output is 20
#  20- True
# Ouput - 20  No need to verify for the next Value!

print(0 or 0)          #----------------------------------------->Output is 0
#  Both are False
#  Output is 0

print(not 10)          #----------------------------------------->Output is False
#  As 10 is true not 10 will be False!

print(not 0)           #----------------------------------------->Output is True
#  As 0 is False not 0 is True!

# %%
#Bitwise Operators
#Do below operations on the values provided below:-
    #Bitwise and(&) -----------------------------------------> 10, 20   -------> Output is 0
    #Bitwise or(|)  -----------------------------------------> 10, 20   -------> Output is 30
    #Bitwise(^)     -----------------------------------------> 10, 20   -------> Output is 30
    #Bitwise negation(~) ------------------------------------> 10       -------> Output is -11
    #Bitwise left shift  ------------------------------------> 10,2     -------> Output is 40
    #Bitwise right shift ------------------------------------> 10,2     -------> Output is 2
#Cross check the output manually

#Bitwise and(&) -----------------------------------------> 10, 20
a = 10   # 0b1010
b = 20   # 0b10100

print(bin(a), bin(b))

# 10 ----- 01010
# 20 ----- 10100
# ----------------
#          00000 -----------> 0
print(a & b)

#Bitwise or(|)  -----------------------------------------> 10, 20

# 10------01010
# 20------10100
# -------------
#         11110  -----------> 30
# print(0b11110)
print(a|b)


#Bitwise(^)     -----------------------------------------> 10, 20 
# 10------01010
# 20------10100
# -------------
#         11110  -----------> 30
print(a^b)

#Bitwise negation(~) ------------------------------------> 10 
# negation of 10 = -(10+1) = -11
print(~10)

#Bitwise left shift  ------------------------------------> 10,2 

# 10 - 0b1010
# 10<<2
# 00000000000000000000000000101000 ----------> 40
print(0b101000)

#Bitwise right shift ------------------------------------> 10,2

# 10- 0b1010
# 10>>2
# 000000000000000000000000000010 ------------> 2
print(0b10)
# Out:
# 0b1010 0b10100
# 0
# 30
# 30
# -11
# 40
# 2

# %%
#What is the output of expression inside print statement. Cross check before running the program.
a = 10
b = 10
print(a is b)          #True or False?
# True
# value in range of 0-256, id of and b are same.
print(a is not b)      #True or False?
# False
# value in range of 0-256, id of and b are same.
a = 1000
b = 1000
print(a is b)          #True or False?
# False
# value not in range of 0-256, id of and b are different.
print(a is not b)      #True or False?
# True
# value not in range of 0-256, id of and b are different.

# %%
#What is the output of expression inside print statement. Cross check before running the program.
print(10+(10*32)//2**5&20+(~(-10))<<2)

                                                          # Operator Precedence
  # (10+320//2**5&20+(~(-10))<<2)                         # ()
  # (10+320//32&20+(~(-10))<<2)                           # **
  # (10+320//32&20+9<<2)                                  # ~,- Bitwise complement and unary Minus
  # (10+10&20+9<<2)                                       # *,/,%,//
  # (20&29<<2)                                            # +,-
  # 29 - 0b11101 - left shift- 1110100  --->116           # <<,>>
  # (20 & 116)                                            # &
  # 20                                                    # ^
                                                          # |
                                                          # >,>=,<,<=,==,!=
                                                          # =,+=,-=...
                                                          # is, is not
                                                          # in, not in
                                                          # not
                                                          # and
                                                          # or
# Out:
# 20

# %%
#Membership operation
#in, not in are two membership operators and it returns boolean value

print('2' in 'Python2.7.8')
# True
print(10 in [10,10.20,10+20j,'Python'])
# True
print(10 in (10,10.20,10+20j,'Python'))
# True
print(2 in {1,2,3})
# True
print(3 in {1:100, 2:200, 3:300})
# True
print(10 in range(20))
# True

# %%
#An integer can be represented in binary, octal or hexadecimal form.
#Declare one binary, one octal and one hexadecimal value and store them in three different variables.
#Convert 9876 to its binary, octal and hexadecimal equivalent and print their corresponding value.

a = 0b11001
b=  0o164
c=  0x74

d= 9876

print(f"Binary: {bin(d)}, Octal:{oct(d)}, Hexadecimal: {hex(d)}")

# Binary: 0b10011010010100, Octal:0o23224, Hexadecimal: 0x2694
# Out:
# Binary: 0b10011010010100, Octal:0o23224, Hexadecimal: 0x2694

# %%
#What will be the output of following:-
a = 0b1010000
print(a)
# Integer Value - 80

b = 0o7436
print(b)
# Integer Value - 3870

c = 0xfade
print(c)
# Integer Value - 64222

print(bin(80))
# Binary Value - 0b1010000

print(oct(3870))
#  Octal Value - 0o7436

print(hex(64222))
# Hexadecimal Value - 0xfade

print(bin(0b1010000))
# Binary - 0b1010000

print(bin(0xfade))
# Binary -  0b1111101011011110

print(oct(0xfade))
# Octal - 0o175336

print(oct(0o7436))
# Octal - 0o7436

print(hex(0b1010000))

# Hexdecimal - 0x50

print(hex(0xfade))

# Hexadecimal - 0xfade
