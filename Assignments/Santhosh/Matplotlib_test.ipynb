# %%
#The generic imports 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Plot a sine and cosine curve
fig, ax = plt.subplots()
x = np.linspace(0, 3 * np.pi, 1000)
ax.plot(x, np.sin(x), lw=3, label='Sine')
ax.plot(x, np.cos(x), lw=3, label='Cosine')

# Set up grid, legend, and limits
ax.grid(True)
ax.legend(frameon=False)
ax.axis('equal')
ax.set_xlim(0, 3 * np.pi);

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,y: "$"+str(x)))

# %%
fig

# %%
vars().keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', 'plt', 'np', 'pd', '_i2', 'fig', 'ax', 'x', '_i3', '_3', '_i4', '_4', '_i5', '_i6', '_i7', '_7', '_i8', '_8', '_i9', '_9', '_i10', '_10', '_i11', '_11', '_i12', '_i13', '_13', '_i14', '_14', '_i15'])

# %%
#figure is used to change the default fig
plt.figure(figsize=(15,5))

# %%
plt.show()

# %%
x= np.arange(1,10)
y1= x*2
y2= x**2
plt.plot(x, y1)
print("Nulllify the previous line")
plt.show()
# Out:
# Nulllify the previous line

# %%
plt.figure(figsize=(15,5))
plt.plot(x,y2)
plt.show()

# %%
type(plt)
# Out:
# module

# %%
type(plt.show())
# Out:
# NoneType
