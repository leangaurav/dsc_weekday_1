# %% [markdown]
# ##### Use AustraliaFiltered.xlsx dataset generated earlier.
#
# - Plot bar chart of total no of immigrants for countires top 5 countires having max no of total immigrants
# - Find total immigrants from each category by area name and plot barchart for each area
# - Plot total immigration trend(immigration of world over the years i.e. year vs Total count for that year) using line plot.
# - Compare Immigration Trend for Asia, Africa and Europe AreaName (Use Line plot).
# - Plot Total Immigrants based on DevelopmenRegion
#
#
# - Plot immigration trend for India using line plot
# - Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants. Use Line plot
# - For the above use area plot with alpha = 0.5
#
#
# - Compare Immigration Trend for top-5 countires using stacked area plot

# %%
import pandas as pd

df = pd.read_excel("C:\Ds\dsc_weekday_1\Assignments\Pratap_J\Australia_Assignment\AustraliaFiltered.xlsx")

# %%
df
# Out:
#                                                 OdName  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                       American Samoa
# 4                                              Andorra
# 5                                               Angola
# 6                                             Anguilla
# 7                                  Antigua and Barbuda
# 8                                            Argentina
# 9                                              Armenia
# 10                                               Aruba
# 11                                           Australia
# 12                                             Austria
# 13                                          Azerbaijan
# 14                                             Bahamas
# 15                                             Bahrain
# 16                                          Bangladesh
# 17                                            Barbados
# 18                                             Belarus
# 19                                             Belgium
# 20                                              Belize
# 21                                               Benin
# 22                                             Bermuda
# 23                                              Bhutan
# 24                    Bolivia (Plurinational State of)
# 25                              Bosnia and Herzegovina
# 26                                            Botswana
# 27                                              Brazil
# 28                              British Virgin Islands
# 29                                   Brunei Darussalam
# ..                                                 ...
# 192                                         Tajikistan
# 193                                           Thailand
# 194          The former Yugoslav Republic of Macedonia
# 195                                        Timor-Leste
# 196                                               Togo
# 197                                            Tokelau
# 198                                              Tonga
# 199                                Trinidad and Tobago
# 200                                            Tunisia
# 201                                             Turkey
# 202                                       Turkmenistan
# 203                           Turks and Caicos Islands
# 204                                             Tuvalu
# 205                                             Uganda
# 206                                            Ukraine
# 207                               United Arab Emirates
# 208  United Kingdom of Great Britain and Northern I...
# 209                        United Republic of Tanzania
# 210                           United States of America
# 211                       United States Virgin Islands
# 212                                            Uruguay
# 213                                         Uzbekistan
# 214                                            Vanuatu
# 215                 Venezuela (Bolivarian Republic of)
# 216                                           Viet Nam
# 217                          Wallis and Futuna Islands
# 218                                     Western Sahara
# 219                                              Yemen
# 220                                             Zambia
# 221                                           Zimbabwe
#
#                             AreaName                    RegName  \
# 0                               Asia              Southern Asia
# 1                             Europe            Southern Europe
# 2                             Africa            Northern Africa
# 3                            Oceania                  Polynesia
# 4                             Europe            Southern Europe
# 5                             Africa              Middle Africa
# 6    Latin America and the Caribbean                  Caribbean
# 7    Latin America and the Caribbean                  Caribbean
# 8    Latin America and the Caribbean              South America
# 9                               Asia               Western Asia
# 10   Latin America and the Caribbean                  Caribbean
# 11                           Oceania  Australia and New Zealand
# 12                            Europe             Western Europe
# 13                              Asia               Western Asia
# 14   Latin America and the Caribbean                  Caribbean
# 15                              Asia               Western Asia
# 16                              Asia              Southern Asia
# 17   Latin America and the Caribbean                  Caribbean
# 18                            Europe             Eastern Europe
# 19                            Europe             Western Europe
# 20   Latin America and the Caribbean            Central America
# 21                            Africa             Western Africa
# 22                  Northern America           Northern America
# 23                              Asia              Southern Asia
# 24   Latin America and the Caribbean              South America
# 25                            Europe            Southern Europe
# 26                            Africa            Southern Africa
# 27   Latin America and the Caribbean              South America
# 28   Latin America and the Caribbean                  Caribbean
# 29                              Asia         South-Eastern Asia
# ..                               ...                        ...
# 192                             Asia               Central Asia
# 193                             Asia         South-Eastern Asia
# 194                           Europe            Southern Europe
# 195                             Asia         South-Eastern Asia
# 196                           Africa             Western Africa
# 197                          Oceania                  Polynesia
# 198                          Oceania                  Polynesia
# 199  Latin America and the Caribbean                  Caribbean
# 200                           Africa            Northern Africa
# 201                             Asia               Western Asia
# 202                             Asia               Central Asia
# 203  Latin America and the Caribbean                  Caribbean
# 204                          Oceania                  Polynesia
# 205                           Africa             Eastern Africa
# 206                           Europe             Eastern Europe
# 207                             Asia               Western Asia
# 208                           Europe            Northern Europe
# 209                           Africa             Eastern Africa
# 210                 Northern America           Northern America
# 211  Latin America and the Caribbean                  Caribbean
# 212  Latin America and the Caribbean              South America
# 213                             Asia               Central Asia
# 214                          Oceania                  Melanesia
# 215  Latin America and the Caribbean              South America
# 216                             Asia         South-Eastern Asia
# 217                          Oceania                  Polynesia
# 218                           Africa            Northern Africa
# 219                             Asia               Western Asia
# 220                           Africa             Eastern Africa
# 221                           Africa             Eastern Africa
#
#                 DevName   1980   1981   1982   1983   1984   1985  ...   2000  \
# 0    Developing regions     10     20     30     30     70    100  ...    100
# 1     Developed regions      0      0      0      0      0      0  ...    110
# 2    Developing regions     10     50     30     10     20     20  ...     20
# 3    Developing regions      0      0      0      0      0     20  ...      0
# 4     Developed regions      0      0     10      0      0      0  ...      0
# 5    Developing regions      0      0      0     10      0      0  ...     10
# 6    Developing regions      0      0      0      0      0      0  ...      0
# 7    Developing regions      0      0      0      0      0      0  ...     10
# 8    Developing regions    570    640    850    520    400    540  ...    380
# 9    Developing regions      0      0      0      0      0      0  ...     20
# 10   Developing regions      0      0      0      0      0      0  ...      0
# 11    Developed regions    280    180    170    150    120    150  ...     10
# 12    Developed regions   4100   3510   5120   1670   1040    970  ...    700
# 13   Developing regions      0      0      0      0      0      0  ...     20
# 14   Developing regions     10     20      0     20     20     20  ...     10
# 15   Developing regions     70    100     80    160    160    140  ...    160
# 16   Developing regions    170    180    220    140    170    220  ...   1180
# 17   Developing regions      0      0      0     10     10     20  ...     10
# 18    Developed regions      0      0      0      0      0      0  ...     20
# 19    Developed regions    230    270    400    280    260    270  ...    440
# 20   Developing regions      0      0      0      0      0      0  ...      0
# 21   Developing regions      0      0      0      0      0      0  ...      0
# 22    Developed regions     20     20     30     30     20     20  ...     20
# 23   Developing regions      0      0     10     10      0     10  ...     40
# 24   Developing regions     20     30     20     30     30     30  ...     30
# 25    Developed regions      0      0      0      0      0      0  ...    560
# 26   Developing regions     20     40     40     80     40     50  ...    420
# 27   Developing regions    270    220    290    230    310    320  ...    540
# 28   Developing regions      0      0      0      0      0     10  ...      0
# 29   Developing regions     80    100    140    150    170    200  ...    680
# ..                  ...    ...    ...    ...    ...    ...    ...  ...    ...
# 192  Developing regions      0      0      0      0      0      0  ...     10
# 193  Developing regions   4730   5300   4230   6790   3530   3100  ...   5070
# 194   Developed regions      0      0      0      0      0      0  ...    430
# 195  Developing regions      0      0      0      0      0      0  ...     50
# 196  Developing regions      0      0      0      0      0      0  ...      0
# 197  Developing regions      0      0      0      0      0      0  ...     10
# 198  Developing regions    130    290    300    200    250    250  ...    320
# 199  Developing regions     20     30     30     10     10     20  ...     20
# 200  Developing regions      0      0      0      0      0      0  ...     10
# 201  Developing regions   1500   1390    870    930   1320   1690  ...   1900
# 202  Developing regions      0      0      0      0      0      0  ...      0
# 203  Developing regions      0      0      0      0      0      0  ...      0
# 204  Developing regions     10     30     30     40     20     30  ...     30
# 205  Developing regions     40     30     30     20     20     30  ...     60
# 206   Developed regions      0      0      0      0      0      0  ...    240
# 207  Developing regions     40     70     80    130    140    140  ...   1080
# 208   Developed regions  43540  57050  51730  31660  25150  27630  ...  51000
# 209  Developing regions     70    120    100     90    110    120  ...    110
# 210   Developed regions  10470  12080  12490  11110  11840  12480  ...  18030
# 211  Developing regions      0      0      0      0      0      0  ...      0
# 212  Developing regions    310    280    220    170    390    280  ...    110
# 213  Developing regions      0      0      0      0      0      0  ...     30
# 214  Developing regions    150    140    170    140    170    170  ...    140
# 215  Developing regions     90     70     70     80     60     80  ...    110
# 216  Developing regions    130     70    200    920   2860   2140  ...   3430
# 217  Developing regions      0      0      0      0      0      0  ...      0
# 218  Developing regions      0      0      0      0      0      0  ...      0
# 219  Developing regions     10      0      0     10     20     10  ...     20
# 220  Developing regions    150    110    120    180    130    170  ...    100
# 221  Developing regions    630   1120   1190    980    640    500  ...    910
#
#       2001   2002   2003   2004   2005   2006   2007   2008    Total
# 0       20     40     70     80    110    180    140    560     4630
# 1      110    200    250    140    130    110    110    140     1910
# 2       30     60     20     20     50     30     30     60      730
# 3        0      0      0      0      0      0      0     10       30
# 4       10     10      0     10     10      0     10     10      100
# 5       10     10     20     10     10     20     30     20      170
# 6        0      0      0      0      0      0      0      0        0
# 7        0     10     10     10     10     10      0      0       80
# 8      430    500    580    560    450    430    460    490    14660
# 9       20     40     30     30     40     20     40     60      560
# 10       0      0      0      0      0      0      0      0       10
# 11      10     10     10    590    700    140    220    780     3690
# 12    1050   1070   1050    800    650    790    570    600    35260
# 13      20     20     30     20     40     30     50     30      310
# 14      20     20     20     20     20     30     20     20      450
# 15     210    250    250    380    460    490    240    220     5510
# 16    1480   1810   2870   2970   1860   2570   3680   3160    30270
# 17      10     30     10     10     20     10     10     10      330
# 18      30     40     50     40     70     50     60     60      650
# 19     480    450    480    410    410    480    530    560    10560
# 20       0      0     10      0      0     10      0      0       40
# 21      10     10     10     10      0      0     90    210      350
# 22      40     40     40     40     20     50     30     50      830
# 23      30     50     40     80     70     90    100    150      850
# 24      30     40     40     40     40     50     50     50     1040
# 25     370    310    240    240    240    250    300    320    12380
# 26     420    450    590    390    260    200    230    260     5550
# 27     680    700    810   1430   2050   2910   3370   4010    23000
# 28       0     10     10      0      0      0     10     20       70
# 29     770    800    880    800    630    750    630    820    16230
# ..     ...    ...    ...    ...    ...    ...    ...    ...      ...
# 192      0      0     10      0      0     10     10     10       50
# 193   6970   7690   7900   7630   8370   9990  11750  13350   162860
# 194    620    580    620    500    510    610    650    660     9630
# 195    170    200    180    280    170    970    450    370     2840
# 196      0      0      0      0      0     10      0     30       40
# 197      0      0      0     10     10     30     10     20      110
# 198    310    270    260    330    330    350    390    640     9780
# 199     20     20     50     30     40     60     30     60      870
# 200      0     30     30     10      0     30     20     10      280
# 201   1890   2470   2490   1850   1720   1690   1860   2080    55890
# 202     10      0      0      0      0      0      0      0       10
# 203      0      0      0      0      0      0      0      0        0
# 204     10     20     20     30     20     20     20     10      730
# 205    140    270    420    770    670    930    820    460     5260
# 206    290    310    290    360    420    360    410    420     7250
# 207   1920   2630   3140   2760   3660   4680   3760   4160    35270
# 208  52940  57330  70150  53140  53300  57250  61490  65160  1333340
# 209    120    170    200    200    930    890   1280    760     6580
# 210  19230  18950  18980  18540  18490  17320  19260  20860   450370
# 211      0      0      0      0      0      0      0      0        0
# 212    100    140    140     80    110     90     90    100     5200
# 213     30     50     70     80     70     60     80    110      820
# 214    170    160    150    400    350    390    400    400     6400
# 215    120    130    130    130    180    160    160    250     2990
# 216   3800   4410   4840   4500   5110   6610   8310  11210   119060
# 217      0      0      0     10      0      0      0      0       10
# 218      0      0      0      0      0      0      0      0        0
# 219     60     40    150     40     20     10     40     40      570
# 220    190    260    430    370    240    410    410    400     5590
# 221   1500   1670   2330   1790   1560   1880   2180   2270    27350
#
# [222 rows x 34 columns]

# %%
# Plot bar chart of total no of immigrants for top 5 countires having max no of total immigrants
# newdf = df.sort_values(by = 'Total', ascending=False)

# newdf.head(5)

# %%
import matplotlib.pyplot as plt

newdf = df.nlargest(5, 'Total')

plt.figure(figsize=(16,6))
plt.bar(newdf.OdName, newdf.Total , color = 'gbycr')
plt.xlabel('Countries')
plt.ylabel('Total Immigrants')
plt.title('Top 5 Countries with highest Immigrants')
plt.xticks(rotation = 10)
plt.show()

# %%
a = df.groupby('AreaName')
plt.figure(figsize=(16,5))
fg = a.size().plot(kind = 'bar')
plt.xticks(rotation=8)
plt.ylabel('Frequency')
plt.xlabel('Area Name')
plt.title('Frequency of the Areas')
plt.show()

# %%
# Find total immigrants from each category by area name and plot barchart for each area
area_name = df.groupby(['AreaName'],as_index=False).sum()
plt.figure(figsize=(16,6))
ax = area_name.Total.plot(kind = 'bar')
lab = ax.get_xticklabels()
lab = df.AreaName.unique()
ax.set_xticklabels(lab)
plt.xticks(rotation=10)
plt.ylabel('Total Immigrants')
plt.xlabel('Area Name')
plt.title('Immigrants by AreaName')
plt.show()

# %%
# Plot total immigration trend(immigration of world over the years i.e. year vs Total count for that year) using line plot.
years = df.columns[4:len(df.columns)-1]
i = 0
year_wise_immigrants = []
while i < len(years):
    year_wise_immigrants.append(df[years[i]].sum(axis = 0))
    i +=1
plt.figure(figsize=(16,5))
plt.plot(years, year_wise_immigrants)
plt.xlabel('Years')
plt.ylabel('Immigrants')
plt.title('Immigrants year-wise')
plt.grid() #optional
plt.show()

# %%
# Compare Immigration Trend for Asia, Africa and Europe AreaName (Use Line plot).
area_africa = df[df['AreaName'] == 'Africa']
area_asia = df[df['AreaName'] == 'Asia']
area_europe = df[df['AreaName'] == 'Europe']
i = 0
asia_immigrants = []
africa_immigrants = []
europe_immigrants = []
while i < len(years):
    asia_immigrants.append(area_asia[years[i]].sum(axis = 0))
    africa_immigrants.append(area_africa[years[i]].sum(axis = 0))
    europe_immigrants.append(area_europe[years[i]].sum(axis = 0))
    i +=1
    
plt.figure(figsize=(16,5))
plt.plot(years, asia_immigrants,label = 'Asia')
plt.plot(years,africa_immigrants,label = 'Africa')
plt.plot(years, europe_immigrants,label = 'Europe')
plt.xlabel('Years')
plt.ylabel('Total Immigrants')
plt.title('Asia, Africa Europe Immigrants year-wise')
# plt.grid() #optional
plt.legend()
plt.show()

# %%
# Plot Total Immigrants based on Development Region
development_region = df.groupby('DevName').sum()
plt.figure(figsize=(16,6))
ax = development_region.Total.plot(kind = 'bar')
lab = ax.get_xticklabels()
lab = df.DevName.unique()
ax.set_xticklabels(lab)
plt.xticks(rotation=0)
plt.ylabel('Total Immigrants')
plt.xlabel('Region Name')
plt.title('Immigrants by Development Region')
plt.show()

# %%
# Plot immigration trend for India using line plot
india = df[df['OdName'] == 'India']
india_immigrants = []
i = 0
while i < len(years):
    india_immigrants.append(india[years[i]].sum(axis = 0))
    i +=1
plt.figure(figsize=(16,5))
plt.plot(years, asia_immigrants)
plt.xlabel('Years')
plt.ylabel('Total Immigrants')
plt.title('Asia, Africa Europe Immigrants year-wise')
# plt.grid() #optional
plt.show()

# %%
# Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants. Use Line plot
top_countries = df.nlargest(5, 'Total')
plt.figure(figsize = (16,6))
for top in top_countries.values:
    country_name = top[0]
    year_count = top[4:33]
    plt.plot(years, year_count,label = country_name)
plt.title('Top 5 countries total immigrant count')
plt.xlabel('year')
plt.ylabel('Total Immigrants')
plt.legend(loc=2)
plt.show()

# %%
# For the above use area plot with alpha = 0.5

top_countries = df.nlargest(5, 'Total')
plt.figure(figsize = (16,6))
country_list = top_countries.OdName
for i in country_list.values:
    country_count = df[df.OdName == i][df.columns[4:len(df.columns)-1]].sum()
    years = country_count.index
    year_count = country_count.values
    plt.fill_between(years, year_count,label=i)
plt.title('Top 5 countries immigrant count')
plt.xlabel('year')
plt.ylabel('Total Immigrants')
plt.legend(loc=2)
plt.show()
# Out:
# ['United Kingdom of Great Britain and Northern Ireland' 'New Zealand'
#  'United States of America'
#  'China, Hong Kong Special Administrative Region' 'China']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-c5c3828b3937> in <module>
#       9     years = country_count.index
#      10     year_count = country_count.values
# ---> 11     plt.fill_between(years, year_count,label=i)
#      12 plt.title('Top 5 countries immigrant count')
#      13 plt.xlabel('year')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2583     return gca().fill_between(
#    2584         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
# -> 2585         **({"data": data} if data is not None else {}), **kwargs)
#    2586
#    2587
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5214
#    5215         # Convert the arrays so we can work with them
# -> 5216         x = ma.masked_invalid(self.convert_xunits(x))
#    5217         y1 = ma.masked_invalid(self.convert_yunits(y1))
#    5218         y2 = ma.masked_invalid(self.convert_yunits(y2))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\ma\core.py in masked_invalid(a, copy)
#    2364         cls = type(a)
#    2365     else:
# -> 2366         condition = ~(np.isfinite(a))
#    2367         cls = MaskedArray
#    2368     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Compare Immigration Trend for top-5 countires using stacked area plot
top_countries = df.nlargest(5, 'Total')
country_lists = []
for i in range(len(top_countries.values)):
    country_list = top_countries.values[i]
    country_lists.append(country_list)

uk = list(country_lists[0][4:33])
nz = list(country_lists[1][4:33])
us = list(country_lists[2][4:33])
hk = list(country_lists[3][4:33])
ch = list(country_lists[4][4:33])

plt.figure(figsize=(16,5))
plt.plot([],[],color ='blue',  label='United Kingdom of Great Britain and Northern Ireland')
plt.plot([],[],color ='orange', label='New Zealand')
plt.plot([],[],color ='brown', label='United States of America')
plt.plot([],[], color ='red',label='China, Hong Kong Special Administrative Region')
plt.plot([],[], color ='green',label='China')

plt.stackplot(years, uk, nz, us, hk, ch,colors = ['blue','orange','brown','red','green'])
plt.legend(loc=2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-360f72a34fd4> in <module>
#      19 plt.plot([],[], color ='green',label='China')
#      20
# ---> 21 plt.stackplot(years, uk, nz, us, hk, ch,colors = ['blue','orange','brown','red','green'])
#      22 plt.legend(loc=2)
#      23
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in stackplot(x, labels, colors, baseline, data, *args, **kwargs)
#    2892     return gca().stackplot(
#    2893         x, *args, labels=labels, colors=colors, baseline=baseline,
# -> 2894         **({"data": data} if data is not None else {}), **kwargs)
#    2895
#    2896
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\stackplot.py in stackplot(axes, x, labels, colors, baseline, *args, **kwargs)
#     107     coll = axes.fill_between(x, first_line, stack[0, :],
#     108                              facecolor=color, label=next(labels, None),
# --> 109                              **kwargs)
#     110     coll.sticky_edges.y[:] = [0]
#     111     r = [coll]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5214
#    5215         # Convert the arrays so we can work with them
# -> 5216         x = ma.masked_invalid(self.convert_xunits(x))
#    5217         y1 = ma.masked_invalid(self.convert_yunits(y1))
#    5218         y2 = ma.masked_invalid(self.convert_yunits(y2))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\ma\core.py in masked_invalid(a, copy)
#    2364         cls = type(a)
#    2365     else:
# -> 2366         condition = ~(np.isfinite(a))
#    2367         cls = MaskedArray
#    2368     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
top_countries = df.nlargest(5,'Total').groupby(['OdName'])
top_sum = top_countries[df.columns[4:len(df.columns)-1]].sum()
top_sum.T.plot.area(stacked=True,figsize=(16,5))
